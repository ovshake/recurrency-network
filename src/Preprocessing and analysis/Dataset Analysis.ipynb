# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %config InlineBackend.figure_format = 'svg'
from pylab import rcParams
rcParams['figure.figsize'] = 5, 4

# %%
df = pd.read_csv("data/ReCurrency-dataset-with-usa-inf-fdi.csv")
print (df.head)
# Out:
# <bound method NDFrame.head of       Unnamed: 0        Date    Open    High     Low  INR Gold Price per Troy  \
# 0              0  2010-01-01  46.610  46.677  46.590                  50606.8
# 1              1  2010-01-04  46.545  46.655  46.245                  51919.8
# 2              2  2010-01-05  46.305  46.305  46.045                  51944.7
# 3              3  2010-01-06  46.165  46.205  45.695                  51816.2
# 4              4  2010-01-07  45.610  45.890  45.570                  51680.7
# 5              5  2010-01-08  45.680  45.900  45.470                  51554.4
# 6              6  2010-01-11  45.510  45.510  45.230                  52271.3
# 7              7  2010-01-12  45.140  45.750  45.100                  52629.4
# 8              8  2010-01-13  45.735  45.775  45.415                  51408.2
# 9              9  2010-01-14  45.490  45.720  45.400                  51927.0
# 10            10  2010-01-15  45.620  45.830  45.410                  51645.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2122 entries, 0 to 2121
# Data columns (total 13 columns):
# Unnamed: 0                                                2122 non-null int64
# Date                                                      2122 non-null object
# Open                                                      2122 non-null float64
# High                                                      2122 non-null float64
# Low                                                       2122 non-null float64
# INR Gold Price per Troy                                   2122 non-null float64
# IND Inflation                                             2122 non-null float64
# USA Inflation                                             2122 non-null float64
# Foreign direct investment net inflows (% of GDP) - IND    2122 non-null float64
# Foreign direct investment net inflows (% of GDP)          2122 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Open', 'High', 'Low', 'INR Gold Price per Troy',
#        'IND Inflation', 'USA Inflation',
#        'Foreign direct investment net inflows (% of GDP) - IND',
#        'Foreign direct investment net inflows (% of GDP)', 'Today Price',
#        'Change', 'Next Price'],
#       dtype='object')

# %%
features=['Date', 'Open', 'High', 'Low', 'INR Gold Price per Troy',
       'IND Inflation', 'USA Inflation',
       'Foreign direct investment net inflows (% of GDP) - IND',
       'Foreign direct investment net inflows (% of GDP)', 'Today Price',
       'Change', 'Next Price']
corr_matrix = df[features].corr()
sns.heatmap(corr_matrix)

# %%
#Scale data and plot
